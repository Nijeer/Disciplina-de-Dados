# %% [markdown]
# ##ifpb
#
# ###info-vesp
#
# topicos em informatica
#
#
#
# > conteudo das aulas

# %%
# ex de adiçao
10+10
# Out:
# 20

# %%
# ex subtraçao
10-5
# Out:
# 5

# %%
# ex multiplicaçao
2*5
# Out:
# 10

# %%
# ex divisao
5/2
# Out:
# 2.5

# %%
# ex exponenciaçao
3**2
# Out:
# 9

# %%
# ex divisao i
5//2
# Out:
# 2

# %%
x = 300

# %%
#string
frase = 'oi'

# %%
#float
y = 10.5

# %%
#type
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'float'>

# %%
# entrada de dados
print("Calcular media aritmetica")
noota1

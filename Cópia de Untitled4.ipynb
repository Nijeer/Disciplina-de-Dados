# %%
import matplotlib.pyplot as plt

# %%
notas = [1, 2, 3, 4, 5, 6]
plt.plot(notas);

# %%
vendas = [15000, 25000, 12500, 8000, 7000, 22000]
meses = ['jan', 'fev', 'mar', 'abr', 'mai', 'jun']
plt.figure(figsize=(10,6))
plt.title("vendas do ano de 2022")
plt.xlabel("mese do ano")
plt.ylabel("valores em R$")
plt.plot(meses, vendas);

# %%
meses = ['07/2022', '08/2022', '09/2022', '10/2022'] 
cand1 =[10, 60, 7, 6]
cand2 =[20, 25, 30, 35]
cand3 =[70, 15, 63, 59]
plt.plot(meses, cand1, label="candidato 1", color='c', marker='*')
plt.plot(meses, cand2, label="candidato 2", color='m', marker='*')
plt.plot(meses, cand3, label="candidato 3", color='y', marker='*')
plt.legend();
plt.ylabel('y')
plt.ylabel('meses')
plt.title('pesquisa eleitoral')
# Out:
# Text(0.5, 1.0, 'pesquisa eleitoral')

# %%
import pandas as pd
df = pd.read_csv('/content/supermarket_sales (1).csv', parse_dates=["Date"])
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df_cidades = df.groupby('City').sum()
df_cidades
# Out:
#            Unit price  Quantity     Tax 5%        Total       cogs  \
# City
# Mandalay     18478.88      1820  5057.0320  106197.6720  101140.64
# Naypyitaw    18567.76      1831  5265.1765  110568.7065  105303.53
# Yangon       18625.49      1859  5057.1605  106200.3705  101143.21
#
#            gross margin percentage  gross income  Rating
# City
# Mandalay               1580.952381     5057.0320  2263.6
# Naypyitaw              1561.904762     5265.1765  2319.9
# Yangon                 1619.047619     5057.1605  2389.2

# %%
x = df_cidades.index
y = df_cidades['Total']
plt.bar(x,y, width=0.5);

# %%
from IPython.core.pylabtools import figsize
df_departamentos = df.groupby('Product line').sum()
plt.figure(figsize=(12,6))
x = df_departamentos.index
y = df_departamentos['Total']
plt.bar(x,y, width=0.5);

# %%
#importando as bbibliotecas
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('/content/supermarket_sales (1).csv', parse_dates=['Date'])
#criando um novo df agrupado por cidades
df_cidades = df.groupby('City').sum()
df_cidades
# Out:
#            Unit price  Quantity     Tax 5%        Total       cogs  \
# City
# Mandalay     18478.88      1820  5057.0320  106197.6720  101140.64
# Naypyitaw    18567.76      1831  5265.1765  110568.7065  105303.53
# Yangon       18625.49      1859  5057.1605  106200.3705  101143.21
#
#            gross margin percentage  gross income  Rating
# City
# Mandalay               1580.952381     5057.0320  2263.6
# Naypyitaw              1561.904762     5265.1765  2319.9
# Yangon                 1619.047619     5057.1605  2389.2

# %%
#dados de eixo x 
x = df_cidades.index
#dados do eixo y
y = df_cidades['Total']

# %%
from matplotlib.projections import ProjectionRegistry
fig, ax = plt.subplots(figsize=(10, 6))
barras = ax.bar(x, y, 0.5, label='Vendas')
ax.set_title("Vendas por cidades", fontname='Arial', fontsize=18, color='r')
ax.set_ylabel("Valores em R$")
ax.set_xlabel("Cidades");
print(barras[0].get_height())
print(barras[1].get_height())
print(barras[2].get_height())
for barra in barras:
  rotulo = f"{barra.get_height():_.2f}"
  rotulo = rotulo.replace('.',',')
  rotulo = rotulo.replace('_','.')
  posx = barra.get_x()
  posy = barra.get_height()
  larg = barra.get_width()
  ax.annotate(rotulo, xy=(posx+larg/2,posy), ha='center', xytext=(0,5), textcoords=('offset points'))
# Out:
# 106197.672
# 110568.7065
# 106200.3705

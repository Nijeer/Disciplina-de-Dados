# %%
Lista = ['Tiringa','charles','Tõe','André','Gabriel']
print(Lista)
Lista.append('Manetikin')
Lista.append('Luiz')
Lista.append(100)
Lista.append(2.5)
print(Lista)
print(101 in Lista)
print('João' in Lista)
print('Mary' in Lista)
Lista.insert(2,101)
print(Lista)
Lista.pop(3)
print(Lista)
Lista.clear()
print(Lista)
# Out:
# ['Tiringa', 'charles', 'Tõe', 'André', 'Gabriel']
# ['Tiringa', 'charles', 'Tõe', 'André', 'Gabriel', 'Manetikin', 'Luiz', 100, 2.5]
# False
# False
# False
# ['Tiringa', 'charles', 101, 'Tõe', 'André', 'Gabriel', 'Manetikin', 'Luiz', 100, 2.5]
# ['Tiringa', 'charles', 101, 'André', 'Gabriel', 'Manetikin', 'Luiz', 100, 2.5]
# []
